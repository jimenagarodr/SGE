# %% [markdown]
# __Cuaderno de trabajo de:__ Nombre Apellido

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
import math 
import itertools

# %% [markdown]
# ### Números pseudo-aleatorios
#
# Cualquier lenguaje de programación tiene una función random, que cuando la llamamos nos devuelve un número pseudo-aleatorio entre 0 y 1. Todos los números entre 0 y 1 son *"igualmente probables"

# %%
random.random?

# %%
#Cada vez que ejecutamos este código obtenemos un número distinto:
random.random()
# Out:
# 0.6641101272825916

# %%
#Generamos 10 números pseudo-aleatorios y los imprimimos
for i in range(10):
    print(random.random())
# Out:
# 0.005132814831390831
# 0.7842678129624113
# 0.4076512959561319
# 0.05347662834336342
# 0.17728708204705956
# 0.9606092896117645
# 0.7551831729753303
# 0.533906718662751
# 0.513073119228285
# 0.8576015847601623

# %% [markdown]
# Además, python nos ofrece otras funciones prácticas:
#
#  - ``random.randint(a,b)`` devuelve un número entero entre a y b (inclusive). Todos los números entre a y b son *"igualmente probables"*.
#  - ``random.choice(lista)`` devuelve un elemento de ``lista`` (que debe ser una lista, cadena de caracteres, conjunto...). Todos los elementos son *"igualmente probables"*.

# %%
for i in range(10):
    print (random.randint(10,20))
# Out:
# 14
# 17
# 13
# 14
# 10
# 19
# 10
# 18
# 10
# 19

# %%
for i in range(10):
    
    print(random.choice([[1,3,2],[4,2]]))
# Out:
# [1, 3, 2]
# [4, 2]
# [1, 3, 2]
# [1, 3, 2]
# [1, 3, 2]
# [1, 3, 2]
# [1, 3, 2]
# [1, 3, 2]
# [4, 2]
# [1, 3, 2]

# %% [markdown]
# ### Semilla aleatoria
#
# Estos números parecen aleatorios, pero **el ordenador los obtiene aplicando reglas deterministas**. Sólo parecen aleatorios, pero *la cpu no lanza dados cuando llamamos a random*.
#
# Esto no es un inconveniente en la práctica, porque son casi imposibles de distinguir de números auténticamente aleatorios.
# De hecho, es una virtud, porque si fijamos la **semilla aleatoria**, podemos obtener exactmente los mismos números, aunque hagamos el cálculo en máquinas distintas varios años después.

# %%
#Si cambias la semilla, las elecciones cambian, pero con la misma semilla
#obtenemos los mismos resultados
random.seed(1)
for i in range(10):
    print (random.random())
for i in range(10):
    print (random.randint(10,20))
for i in range(10):
    print(random.choice('AEIOU'))
for i in range(10):
    print(random.choice(["hola","adiós","¿Qué tal?", "ahora vengo"]))
# Out:
# 0.13436424411240122
# 0.8474337369372327
# 0.763774618976614
# 0.2550690257394217
# 0.49543508709194095
# 0.4494910647887381
# 0.651592972722763
# 0.7887233511355132
# 0.0938595867742349
# 0.02834747652200631
# 16
# 16
# 19
# 10
# 17
# 14
# 13
# 19
# 11
# 15
# A
# A
# A
# U
# A
# O
# E
# O
# A
# U
# adiós
# ahora vengo
# ahora vengo
# adiós
# ¿Qué tal?
# adiós
# adiós
# ahora vengo
# ¿Qué tal?
# hola

# %% [markdown]
# ### Distribuciones de números aleatorios
#
# El bloque de funciones de distribuciones ofrece numerosas funciones que permiten generar un array de números aleatorios a partir de distribuciones de todo tipo, vamos algunos ejemplos:
#
# #### Distribución uniforme

# %%
N_puntos = 10000
ini = 1
fin = 6
bins = 6

x = np.random.uniform(ini, fin, N_puntos)
plt.hist(x, bins,density=True)  #desity=True integra la curva a 1
plt.hlines(1/10, ini, fin, linestyles ="-", colors ="r")
plt.show()

# %% [markdown]
# #### Distribución normal
#
# Es una distribución gausiana
# $$p(x) = \frac{1}{\sqrt{ 2 \pi \sigma^2 }} e^{ - \frac{ (x - \mu)^2 } {2 \sigma^2} }$$

# %%
ini = 0
fin = 10
bins = 100
sigma = 1.0
mu = 5.0


fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,4))

N_puntos = 1000
x = np.random.normal(mu, sigma, N_puntos)
ax1.hist(x, bins,density=True)
ax1.set_title("N = "+str(N_puntos))

N_puntos = 10000
x = np.random.normal(mu, sigma, N_puntos)
ax2.hist(x, bins,density=True)
ax2.set_title("N = "+str(N_puntos))

N_puntos = 100000
x = np.random.normal(mu, sigma, N_puntos)
ax3.hist(x, bins,density=True)
ax3.set_title("N = "+str(N_puntos))

x = np.arange(0, 10, 0.1)
y=[]
for i in range(len(x)):
    y.append(1/math.sqrt(2*math.pi*sigma**2)*math.exp(-((x[i]-mu)**2)/(2*sigma**2)))
ax1.plot(x,y)
ax2.plot(x,y)
ax3.plot(x,y)

plt.show()

# %% [markdown]
# #### Distribución exponencial
#
# Es una distribución exponencial
# $$  f(x; \frac{1}{\beta}) = \frac{1}{\beta} \exp(-\frac{x}{\beta})  $$

# %%
ini = 0
fin = 10
bins = 100
beta = 1.0

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,4))

N_puntos = 1000
x = np.random.exponential(beta, N_puntos)
ax1.hist(x, bins,density=True)
ax1.set_title("N = "+str(N_puntos))

N_puntos = 10000
x = np.random.exponential(beta, N_puntos)
ax2.hist(x, bins,density=True)
ax2.set_title("N = "+str(N_puntos))

N_puntos = 100000
x = np.random.exponential(beta, N_puntos)
ax3.hist(x, bins,density=True)
ax3.set_title("N = "+str(N_puntos))

x = np.arange(0, 10, 0.1)
y=[]
for i in range(len(x)):
    y.append(1/beta*math.exp(-x[i]/beta))
ax1.plot(x,y)
ax2.plot(x,y)
ax3.plot(x,y)

plt.show()

# %% [markdown]
# <hr>
# <b><font color='red'>Ejercicio 01</font></b>
#
# El método **Montecarlo** es un método no determinista o estadístico numérico, usado para aproximar expresiones matemáticas complejas y costosas de evaluar con exactitud. El método se llamó así en referencia al Casino de Montecarlo (Mónaco) por ser “la capital del juego de azar”, al ser la ruleta un generador simple de números aleatorios. El nombre y el desarrollo sistemático de los métodos de Montecarlo datan aproximadamente de 1944 testee combinaciones posibles.
#
# Vamos a calcular el valor de $\pi$, para ello, si $X$ e $Y$ son dos variables aleatorias continuas uniformes en el intervalo (-1,1) y son independientes.
# $\pi$ Vendrá dada por la probabilidad de que $X^2 + Y^2  \leq 1$, es decir:
# $$\pi = \frac{4*\text{nº puntos que caén dentro}}{\text{nº total de intentos}}$$
# Obten tambien una gráfica como la que se muestra a continuación.

# %%
import matplotlib.pyplot as plt

def f(x, y):
    return (x**2)+(y**2)

N=100000 #número de intentos
cont_dentro = 0
fig = plt.figure(figsize=(8,8))
ini = -1
fin = 1
xLista = []
yLista = []
colores= []

for i in range (N):
    x = 1-2*random.random()
    y = 1-2*random.random()
    xLista.append(x)
    yLista.append(y)
    if (x*x + y*y <= 1):
        colores.append("magenta")
        cont_dentro+=1
    else :
        colores.append("blue")

plt.scatter(xLista, yLista, c=colores, s=0.5)
plt.show()

miPi = 4*cont_dentro / N
print("El valor de 𝜋 es " + str(miPi))
# Out:
# El valor de 𝜋 es 3.14316

# %% [markdown]
# <img src="f6.png">

# %% [markdown]
# <hr>
# <b><font color='red'>Ejercicio 02</font></b>
#
# Crea un histograma en que se vea la distribución que saldría al sumar dos dados, tiene que verse una gráfica como la que se muestra a continuación

# %%
N_puntos = 10000
ini = 1
fin = 7


dado1 = np.random.randint(ini, fin, N_puntos)
dado2 = np.random.randint(ini, fin, N_puntos)
x = dado1 + dado2

plt.hist(x, bins=range(1, 14), density=True)
plt.grid()
plt.show()

# %% [markdown]
# <img src="f7.png">

# %% [markdown]
# <hr>
# <b><font color='red'>Ejercicio 03</font></b>
#
# Al implementar MD5, obtendremos como resultado, una cadena alfanumérica de 32 caracteres hexadecimales. Ocupando siempre 16 Bytes de memoria.
#
# El siguiente pin = '4aca32b706287f13903f08b7aab38f79', ha sido codificado con md5 "hashlib.md5(b'****')", para ello han utilizado dos carácteres en mayúsculas ('ABCDEF')  y dos números (0-9) , haz una función que obtenga el pin descodificado utilizando random.
#
# ¿Cuántos intentos ha relizado hasta que la ha descubierto?
# Realiza el ejercicio varias veces y haz un histograma.

# %%
import hashlib as hs

cantIntentos=[]
for i in range(1,10):
    encontrado = False
    intentos = 0
    while not encontrado:
        letra1 = random.choice(['A', 'B', 'C', 'D', 'E', 'F'])
        letra2 = random.choice(['A', 'B', 'C', 'D', 'E', 'F'])
        num1 = random.choice(['1','2','3','4','5','6','7','8','9'])
        num2 = random.choice(['1','2','3','4','5','6','7','8','9'])
        inp_list = [letra1, letra2, num1, num2]
        for i in list(itertools.permutations(inp_list, r=4)):
            intentos+=1
            a=i[0] + i[1] + i[2] + i[3]
            result = hs.md5(a.encode('utf-8'))
            if (result.hexdigest() == "4aca32b706287f13903f08b7aab38f79"):
                encontrado = True
                codigo = a
    cantIntentos.append(intentos)
    

    
print("LO ENCONTRE: " + codigo)
x = np.array(cantIntentos)
plt.hist(x, bins=50, density=True)
plt.grid()
plt.show()
# Out:
# LO ENCONTRE: 1A2D

# %% [markdown]
# <hr>
# <b><font color='red'>Ejercicio 04</font></b>
#
# <img src="ruleta.png">
#
# La ruleta europea tiene 37 números, de los cuales 18 son rojos, 18 negros y el 0, que es verde, entre las diversas apuestas existe la de de apostar todo a rojos o negros, en este caso si se gana, se ganaría lo mismo que se ha apostado.
#
# Haz la siguiente simulación, empezando con una cantidad de 1000 euros, apostando de forma constante 50 Euros, haz que la maquina apueste siempre a los pares o a los impares, en ambos casos si sale 0 se perderia lo apostado.

# %%
def ruleta():
    cant = 1000
    tiros=0
    apuesta_constante = 50
    # pares == 0
    # impares == 1
    while cant > 0:
        cant-=apuesta_constante
        randomN = random.randint(0, 36)
        parOImp = random.randint(0,1)
        if(randomN != 0):
    #         mensaje = 'NO'
            if(randomN%2 == parOImp):
                cant+=apuesta_constante*2
    #             mensaje = 'SI'
    #         print (str(randomN) + " es " + str(parOImp) + "? --> " + mensaje)
        tiros+=1
    return tiros

print("El jugador se ha arruinado en " + str(ruleta()) + " intentos")
# Out:
# El jugador se ha arruinado en 1238 intentos

# %% [markdown]
# <hr>
# <b><font color='red'>Ejercicio 05</font></b>
#
# Utiliza 10 jugadores y haz el promedio de veces en lo que tardarían en arruinarse

# %%
intentos =[]
for i in range(10):
    intentos_arruinado = ruleta()
    print("El jugador " + str(i+1) + " se ha arruinado en " + str(intentos_arruinado) + " intentos")
    intentos.append(intentos_arruinado)
    
print("Promedio de intentos que tardan en arruinarse: " + str(np.average(intentos)))
# Out:
# El jugador 1 se ha arruinado en 120 intentos
# El jugador 2 se ha arruinado en 526 intentos
# El jugador 3 se ha arruinado en 344 intentos
# El jugador 4 se ha arruinado en 104 intentos
# El jugador 5 se ha arruinado en 390 intentos
# El jugador 6 se ha arruinado en 412 intentos
# El jugador 7 se ha arruinado en 210 intentos
# El jugador 8 se ha arruinado en 460 intentos
# El jugador 9 se ha arruinado en 322 intentos
# El jugador 10 se ha arruinado en 146 intentos
# Promedio de intentos que tardan en arruinarse: 303.4

# %% [markdown]
# <hr>
# <b><font color='red'>Ejercicio 06</font></b>
#
# Obten la siguiente evolución respecto el número de jugadores:
#
#     print("%6d" % njugadores,"%.1f" % a.mean(),"%.0f"%a.std())
#         10 636.8 624
#         20 603.0 799
#         50 799.2 875
#        100 558.1 500
#        200 921.6 1236
#        500 744.2 936
#       1000 726.1 1021
#       5000 734.3 967
#      10000 734.5 1021

# %%
intentos =[]
for i in range(10000):
    intentos_arruinado = ruleta()
    intentos.append(intentos_arruinado)
    if (i == 10):
        print("%6d" % i,"%.1f" % np.average(intentos),"%.0f"%np.std(intentos))
    elif(i==20):
        print("%6d" % i,"%.1f" % np.average(intentos),"%.0f"%np.std(intentos))
    elif(i==50):
        print("%6d" % i,"%.1f" % np.average(intentos),"%.0f"%np.std(intentos))
    elif(i==100):
        print("%6d" % i,"%.1f" % np.average(intentos),"%.0f"%np.std(intentos))
    elif(i==200):
        print("%6d" % i,"%.1f" % np.average(intentos),"%.0f"%np.std(intentos))
    elif(i==500):
        print("%6d" % i,"%.1f" % np.average(intentos),"%.0f"%np.std(intentos))
    elif(i==1000):
        print("%6d" % i,"%.1f" % np.average(intentos),"%.0f"%np.std(intentos))
    elif(i==5000):
        print("%6d" % i,"%.1f" % np.average(intentos),"%.0f"%np.std(intentos))
    elif(i==10000):
        print("%6d" % i,"%.1f" % np.average(intentos),"%.0f"%np.std(intentos))
# Out:
#     10 901.6 802
#     20 892.9 1316
#     50 612.7 910
#    100 611.4 809
#    200 636.4 834
#    500 678.1 913
#   1000 726.8 1027
#   5000 742.3 1023

# %% [markdown]
# <hr>
# <b><font color='red'>Ejercicio 07</font></b>
#
# Empezamos con el problema del viajante, (Travelling Salesman Problem) responde a la siguiente pregunta: dada una lista de ciudades y las distancias entre cada par de ellas, ¿cuál es la ruta más corta posible que visita cada ciudad exactamente una vez y al finalizar regresa a la ciudad origen? Este es un problema NP-Hard dentro en la optimización combinatoria, muy importante en investigación operativa y en ciencias de la computación.
# En el siguiente problema partiendo de Madrid tenemos que pasar por las siguientes ciudades

# %%
from ipyleaflet import Map, Polyline
from ipyleaflet import Map, basemaps, basemap_to_tiles, Circle


ciudad = [[40.4950873744,-3.71704619215],
[41.6207742504,-2.58874304739],
[38.4786378049,-0.568699068376],
[42.0439686698,1.04798206104],
[36.5538729195,-5.7604183752],
[40.8049892162,-6.06541224773],
[42.435764706,-8.46106294738],
[38.0165122783,-3.44169215171],
[41.6203648019,-1.06449678144],
[42.1280117119,2.6735559327],
[43.292357861,-5.99350932547]]
 
line = Polyline(
    locations=ciudad,
    color="blue" ,
    weight = 2,
    fill=False
)
c=ciudad[0]
m = Map(center = ciudad[0], zoom =5.4)
for i in ciudad:
    circle = Circle()
    circle.location = i
    circle.radius = 5000
    circle.color = "blue"
    circle.fill_color = "blue"
    m.add_layer(circle)
m.add_layer(line)
m
# Out:
# Map(center=[40.4950873744, -3.71704619215], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_i…
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ipywidgets\widgets\widget.py:707, in Widget._handle_msg(self, msg)
#     705         if 'buffer_paths' in data:
#     706             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 707         self.set_state(state)
#     709 # Handle a state request.
#     710 elif method == 'request_state':
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ipywidgets\widgets\widget.py:589, in Widget.set_state(self, sync_data)
#     586 if name in self.keys:
#     587     from_json = self.trait_metadata(name, 'from_json',
#     588                                     self._trait_from_json)
# --> 589     self.set_trait(name, from_json(sync_data[name], self))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\traitlets\traitlets.py:1609, in HasTraits.set_trait(self, name, value)
#    1607     raise TraitError(f"Class {cls.__name__} does not have a trait named {name}")
#    1608 else:
# -> 1609     getattr(cls, name).set(self, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\traitlets\traitlets.py:689, in TraitType.set(self, obj, value)
#     688 def set(self, obj, value):
# --> 689     new_value = self._validate(obj, value)
#     690     try:
#     691         old_value = obj._trait_values[self.name]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\traitlets\traitlets.py:721, in TraitType._validate(self, obj, value)
#     719     return value
#     720 if hasattr(self, "validate"):
# --> 721     value = self.validate(obj, value)  # type:ignore[attr-defined]
#     722 if obj._cross_validation_lock is False:
#     723     value = self._cross_validate(obj, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\traitlets\traitlets.py:2294, in Float.validate(self, obj, value)
#    2292     value = float(value)
#    2293 if not isinstance(value, float):
# -> 2294     self.error(obj, value)
#    2295 return _validate_bounds(self, obj, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\traitlets\traitlets.py:827, in TraitType.error(self, obj, value, error, info)
#     821 else:
#     822     e = "The '{}' trait expected {}, not {}.".format(
#     823         self.name,
#     824         self.info(),
#     825         describe("the", value),
#     826     )
# --> 827 raise TraitError(e)
#
# TraitError: The 'east' trait of a Map instance expected a float, not the NoneType None.
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ipywidgets\widgets\widget.py:707, in Widget._handle_msg(self, msg)
#     705         if 'buffer_paths' in data:
#     706             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 707         self.set_state(state)
#     709 # Handle a state request.
#     710 elif method == 'request_state':
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ipywidgets\widgets\widget.py:589, in Widget.set_state(self, sync_data)
#     586 if name in self.keys:
#     587     from_json = self.trait_metadata(name, 'from_json',
#     588                                     self._trait_from_json)
# --> 589     self.set_trait(name, from_json(sync_data[name], self))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\traitlets\traitlets.py:1609, in HasTraits.set_trait(self, name, value)
#    1607     raise TraitError(f"Class {cls.__name__} does not have a trait named {name}")
#    1608 else:
# -> 1609     getattr(cls, name).set(self, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\traitlets\traitlets.py:689, in TraitType.set(self, obj, value)
#     688 def set(self, obj, value):
# --> 689     new_value = self._validate(obj, value)
#     690     try:
#     691         old_value = obj._trait_values[self.name]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\traitlets\traitlets.py:721, in TraitType._validate(self, obj, value)
#     719     return value
#     720 if hasattr(self, "validate"):
# --> 721     value = self.validate(obj, value)  # type:ignore[attr-defined]
#     722 if obj._cross_validation_lock is False:
#     723     value = self._cross_validate(obj, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\traitlets\traitlets.py:2294, in Float.validate(self, obj, value)
#    2292     value = float(value)
#    2293 if not isinstance(value, float):
# -> 2294     self.error(obj, value)
#    2295 return _validate_bounds(self, obj, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\traitlets\traitlets.py:827, in TraitType.error(self, obj, value, error, info)
#     821 else:
#     822     e = "The '{}' trait expected {}, not {}.".format(
#     823         self.name,
#     824         self.info(),
#     825         describe("the", value),
#     826     )
# --> 827 raise TraitError(e)
#
# TraitError: The 'east' trait of a Map instance expected a float, not the NoneType None.

# %% [markdown]
# Crea una función que obtenga el recorrido realizado, testeala con el orden actual de ciudades
#
#     sol : d = 435.6697061255633

# %%
import math
# DESORDENAR CIUDADES


def desordenarCiudades(ciudad):
    ciudadesDesordenadas = [ciudad[0]]
    while len(ciudadesDesordenadas) != 10:
        indCiudad = random.randint(1,10)
        if ciudad[indCiudad] not in ciudadesDesordenadas:
            ciudadesDesordenadas.append(ciudad[indCiudad])
    return ciudadesDesordenadas
        
    
def getDist(origen, destino):
    # distancia = Raiz de --> (x-x) ^2 + (y-y)^2
    distanciaSuma = (origen[0]-destino[0])**2 + (origen[1]-destino[1])**2
    return math.sqrt(distanciaSuma) 

def getDistanciaTotal(ciudDes):
    distancia = 0
    for i in range (1,len(ciudDes)):
        distancia+= getDist(ciudDes[i-1], ciudDes[i])

    return distancia
        
ciudDes = desordenarCiudades(ciudad)
print(str(getDistanciaTotal(ciudDes)))
# Out:
# 41.631425775127624

# %% [markdown]
# Haz un algoritmo que utilice el **método montecarlo**, para este problema haz que desde desde la ciudad[0] se minimice la distancia recorrida, utilizalo con almenos 1000000 permutaciones aleatorias para mejorar el recorrido.

# %%
mejorDist = 10000000000000
mejorComb = []
for i in range(1, 1000000):
    ciudDes = desordenarCiudades(ciudad)
    dist = getDistanciaTotal(ciudDes) 
    if (dist < mejorDist):
        mejorDist = dist
        mejorComb = ciudDes 
print("MEJOR DISTANCIA: " + str(mejorDist))
print("Mejor ruta: " + str(mejorComb))
# Out:
# MEJOR DISTANCIA: 24.1838191194306
# Mejor ruta: [[40.4950873744, -3.71704619215], [41.6207742504, -2.58874304739], [41.6203648019, -1.06449678144], [42.0439686698, 1.04798206104], [42.1280117119, 2.6735559327], [38.4786378049, -0.568699068376], [38.0165122783, -3.44169215171], [36.5538729195, -5.7604183752], [40.8049892162, -6.06541224773], [43.292357861, -5.99350932547]]

# %% [markdown]
# Utiliza itertools para generar todas las permutaciones y obtener la solución

# %% [markdown]
# <img src="permutations_ciudades.png">

# %%
mejorDist = 10000000000000
mejorComb = []
ciudad = [[40.4950873744,-3.71704619215],
[41.6207742504,-2.58874304739],
[38.4786378049,-0.568699068376],
[42.0439686698,1.04798206104],
[36.5538729195,-5.7604183752],
[40.8049892162,-6.06541224773],
[42.435764706,-8.46106294738],
[38.0165122783,-3.44169215171],
[41.6203648019,-1.06449678144],
[42.1280117119,2.6735559327],
[43.292357861,-5.99350932547]]

A=ciudad[1:]
print(A)
print("....")

dmin=getDistanciaTotal(ciudad)
ciudad_min=ciudad

for i in list(itertools.permutations(A, r=len(A))):
    aux=[]
    aux.append(ciudad[0])
    for j in i:
        aux.append(j)
    dist = getDistanciaTotal(i) 
    if (dist < dmin):
        dmin = dist
        ciudad_min = aux


print("MEJOR DIST: " + str(dmin))
print("MEJOR COMBINACION: " + str(ciudad_min))



line = Polyline(
    locations=ciudad_min,
    color="blue" ,
    weight = 2,
    fill=False
)
c=ciudad_min[0]
m = Map(center = ciudad_min[0], zoom =5.4)
for i in ciudad_min:
    circle = Circle()
    circle.location = i
    circle.radius = 5000
    circle.color = "blue"
    circle.fill_color = "blue"
    m.add_layer(circle)
m.add_layer(line)
m
# Out:
# [[41.6207742504, -2.58874304739], [38.4786378049, -0.568699068376], [42.0439686698, 1.04798206104], [36.5538729195, -5.7604183752], [40.8049892162, -6.06541224773], [42.435764706, -8.46106294738], [38.0165122783, -3.44169215171], [41.6203648019, -1.06449678144], [42.1280117119, 2.6735559327], [43.292357861, -5.99350932547]]
# ....
# MEJOR DIST: 24.05585037820575
# MEJOR COMBINACION: [[40.4950873744, -3.71704619215], [42.435764706, -8.46106294738], [43.292357861, -5.99350932547], [40.8049892162, -6.06541224773], [36.5538729195, -5.7604183752], [38.0165122783, -3.44169215171], [38.4786378049, -0.568699068376], [41.6207742504, -2.58874304739], [41.6203648019, -1.06449678144], [42.0439686698, 1.04798206104], [42.1280117119, 2.6735559327]]
# Map(center=[40.4950873744, -3.71704619215], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_i…

# %%
# print (ciudad)
# #for i in list(itertools.permutations(ciudad, r=11)):
# #     dist = getDistanciaTotal(i) 
# #     if (dist < mejorDist):
# #         mejorDist = dist
# #         mejorComb = ciudDes 
# # print("MEJOR DISTANCIA: " + str(mejorDist))
# # print("Mejor ruta: " + str(mejorComb))


# #Tarda mucho. 
# # Mejor distancia es 24.90250743446447
# # Mejor combinacion = [[40.4950873744, -3.71704619215], [41.6203648019, -1.06449678144], [40.8049892162, -6.06541224773], [38.0165122783, -3.44169215171], [41.6207742504, -2.58874304739], [42.0439686698, 1.04798206104], [42.1280117119, 2.6735559327], [36.5538729195, -5.7604183752], [38.4786378049, -0.568699068376], [42.435764706, -8.46106294738]]
# mejorDist = 24.90250743446447
# mejorComb = [
#     [40.4950873744, -3.71704619215], 
#     [38.4786378049, -0.568699068376], 
#     [40.8049892162, -6.06541224773], [43.292357861, -5.99350932547], [41.6203648019, -1.06449678144], [42.1280117119, 2.6735559327], [42.0439686698, 1.04798206104], [38.0165122783, -3.44169215171], [42.435764706, -8.46106294738], [36.5538729195, -5.7604183752]]


# line = Polyline(
#     locations=mejorComb,
#     color="blue" ,
#     weight = 2,
#     fill=False
# )
# c=mejorComb[0]
# m = Map(center = mejorComb[0], zoom =5.4)
# for i in mejorComb:
#     circle = Circle()
#     circle.location = i
#     circle.radius = 5000
#     circle.color = "blue"
#     circle.fill_color = "blue"
#     m.add_layer(circle)
# m.add_layer(line)
# m
# Out:
# [[40.4950873744, -3.71704619215], [41.6207742504, -2.58874304739], [38.4786378049, -0.568699068376], [42.0439686698, 1.04798206104], [36.5538729195, -5.7604183752], [40.8049892162, -6.06541224773], [42.435764706, -8.46106294738], [38.0165122783, -3.44169215171], [41.6203648019, -1.06449678144], [42.1280117119, 2.6735559327], [43.292357861, -5.99350932547]]
# Map(center=[40.4950873744, -3.71704619215], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_i…
